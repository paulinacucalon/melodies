# %%
import numpy as np
import pandas as pd
import mido
from pathlib import Path

# %% [markdown]
# Expects to have the dataset unzipped at the project root under `maestro`.
# Not committed due to size.

# %%
data_dir = Path('../maestro/maestro-v3.0.0/')
df = pd.read_csv(data_dir / 'maestro-v3.0.0.csv')
df.head()
# Out:
#    canonical_composer                canonical_title       split  year  \
# 0          Alban Berg                   Sonata Op. 1       train  2018
# 1          Alban Berg                   Sonata Op. 1       train  2008
# 2          Alban Berg                   Sonata Op. 1       train  2017
# 3  Alexander Scriabin  24 Preludes Op. 11, No. 13-24       train  2004
# 4  Alexander Scriabin               3 Etudes, Op. 65  validation  2006
#
#                                        midi_filename  \
# 0  2018/MIDI-Unprocessed_Chamber3_MID--AUDIO_10_R...
# 1  2008/MIDI-Unprocessed_03_R2_2008_01-03_ORIG_MI...
# 2  2017/MIDI-Unprocessed_066_PIANO066_MID--AUDIO-...
# 3  2004/MIDI-Unprocessed_XP_21_R1_2004_01_ORIG_MI...
# 4  2006/MIDI-Unprocessed_17_R1_2006_01-06_ORIG_MI...
#
#                                       audio_filename    duration
# 0  2018/MIDI-Unprocessed_Chamber3_MID--AUDIO_10_R...  698.661160
# 1  2008/MIDI-Unprocessed_03_R2_2008_01-03_ORIG_MI...  759.518471
# 2  2017/MIDI-Unprocessed_066_PIANO066_MID--AUDIO-...  464.649433
# 3  2004/MIDI-Unprocessed_XP_21_R1_2004_01_ORIG_MI...  872.640588
# 4  2006/MIDI-Unprocessed_17_R1_2006_01-06_ORIG_MI...  397.857508

# %% [markdown]
# Can load the file and explore the `messages`, which hold notes and other actions.
# Likely to just have track 0 and 1 per file.
# Track 0 holds only metadata, track 1 holds the whole song.

# %%
filename = data_dir / df.iloc[0]['midi_filename']
print(filename)
mid = mido.MidiFile(filename)
messages = []
for i, track in enumerate(mid.tracks):
    print('Track {}: {}'.format(i, track.name))
    for msg in track:
        messages.append(msg.dict())
# Out:
# ..\maestro\maestro-v3.0.0\2018\MIDI-Unprocessed_Chamber3_MID--AUDIO_10_R3_2018_wav--1.midi
# Track 0:
# Track 1:

# %% [markdown]
# Looking at the start of the messages, we should be able to roughly figure out what kind of note they are by combining time, note ons and offs, and the time signature metadata.
# Need to verify on all the files, but looks like `note_off` actions might not be included.
# Instead, setting the velocity to 0 is likely how the note ends.
#
# Time is incremental, so the second note is hit 615 ticks after the first.
# Then 20 ticks later, the first note lifts off.
#
# It doesn't look like chords are actually hit at the same time.
# In the sheet music, rows 13, 15, 17, and 18 are all part of a chord played at the same time.
# The ticks are so granular that here they range across ~30 ticks.

# %%
messages = pd.DataFrame(messages)
print(messages.shape)
messages.head(20)
# Out:
# (23945, 13)
#               type     tempo  time  numerator  denominator  clocks_per_click  \
# 0        set_tempo  500000.0     0        NaN          NaN               NaN
# 1   time_signature       NaN     0        4.0          4.0              24.0
# 2     end_of_track       NaN     1        NaN          NaN               NaN
# 3   program_change       NaN     0        NaN          NaN               NaN
# 4   control_change       NaN     0        NaN          NaN               NaN
# 5          note_on       NaN   755        NaN          NaN               NaN
# 6          note_on       NaN   615        NaN          NaN               NaN
# 7          note_on       NaN    20        NaN          NaN               NaN
# 8          note_on       NaN    74        NaN          NaN               NaN
# 9   control_change       NaN   128        NaN          NaN               NaN
# 10  control_change       NaN    15        NaN          NaN               NaN
# 11  control_change       NaN    16        NaN          NaN               NaN
# 12  control_change       NaN    15        NaN          NaN               NaN
# 13         note_on       NaN    11        NaN          NaN               NaN
# 14  control_change       NaN     3        NaN          NaN               NaN
# 15         note_on       NaN     2        NaN          NaN               NaN
# 16  control_change       NaN    14        NaN          NaN               NaN
# 17         note_on       NaN     5        NaN          NaN               NaN
# 18         note_on       NaN     2        NaN          NaN               NaN
# 19  control_change       NaN     8        NaN          NaN               NaN
#
#     notated_32nd_notes_per_beat  program  channel  control  value  note  \
# 0                           NaN      NaN      NaN      NaN    NaN   NaN
# 1                           8.0      NaN      NaN      NaN    NaN   NaN
# 2                           NaN      NaN      NaN      NaN    NaN   NaN
# 3                           NaN      0.0      0.0      NaN    NaN   NaN
# 4                           NaN      NaN      0.0     64.0  127.0   NaN
# 5                           NaN      NaN      0.0      NaN    NaN  67.0
# 6                           NaN      NaN      0.0      NaN    NaN  72.0
# 7                           NaN      NaN      0.0      NaN    NaN  67.0
# 8                           NaN      NaN      0.0      NaN    NaN  72.0
# 9                           NaN      NaN      0.0     64.0  117.0   NaN
# 10                          NaN      NaN      0.0     64.0  111.0   NaN
# 11                          NaN      NaN      0.0     64.0  107.0   NaN
# 12                          NaN      NaN      0.0     64.0  103.0   NaN
# 13                          NaN      NaN      0.0      NaN    NaN  78.0
# 14                          NaN      NaN      0.0     64.0   98.0   NaN
# 15                          NaN      NaN      0.0      NaN    NaN  71.0
# 16                          NaN      NaN      0.0     64.0   93.0   NaN
# 17                          NaN      NaN      0.0      NaN    NaN  61.0
# 18                          NaN      NaN      0.0      NaN    NaN  67.0
# 19                          NaN      NaN      0.0     64.0   85.0   NaN
#
#     velocity
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# 5       52.0
# 6       67.0
# 7        0.0
# 8        0.0
# 9        NaN
# 10       NaN
# 11       NaN
# 12       NaN
# 13      65.0
# 14       NaN
# 15      45.0
# 16       NaN
# 17      39.0
# 18      39.0
# 19       NaN

# %% [markdown]
# No `note_off` messages as mentioned.
# Control changes are things like changing volume or pedals.

# %%
messages.type.value_counts()
# Out:
# type
# control_change    15546
# note_on            8394
# end_of_track          2
# set_tempo             1
# time_signature        1
# program_change        1
# Name: count, dtype: int64

# %% [markdown]
# Type 64 is sustain pedal on and off.
# Type 67 is soft pedal on and off.

# %%
messages.control.value_counts()
# Out:
# control
# 64.0    13165
# 67.0     2381
# Name: count, dtype: int64

# %% [markdown]
# Seems like we mostly care about `note_on` events where the velocity is > 0, meaning the note was played.
# This should be a way to create a vectorized `bag of notes`, though it should be sorted by note.
# MIDI numbers appear to range from 21 to 108 for 88 total notes.
# 72 of them are included in this song, which actually seems quite high.

# %%
messages[messages.velocity > 0].note.value_counts()
# Out:
# note
# 62.0     146
# 66.0     140
# 60.0     140
# 71.0     132
# 67.0     131
#         ...
# 28.0       4
# 95.0       3
# 29.0       3
# 27.0       1
# 102.0      1
# Name: count, Length: 72, dtype: int64

# %% [markdown]
# Theoretically could have multiple channels, but I don't expect that's happening with our simple piano files.

# %%
messages.channel.value_counts()
# Out:
# channel
# 0.0    23941
# Name: count, dtype: int64

# %%
messages['time_from_start'] = messages.time.cumsum()
messages.head(20)
# Out:
#               type     tempo  time  numerator  denominator  clocks_per_click  \
# 0        set_tempo  500000.0     0        NaN          NaN               NaN
# 1   time_signature       NaN     0        4.0          4.0              24.0
# 2     end_of_track       NaN     1        NaN          NaN               NaN
# 3   program_change       NaN     0        NaN          NaN               NaN
# 4   control_change       NaN     0        NaN          NaN               NaN
# 5          note_on       NaN   755        NaN          NaN               NaN
# 6          note_on       NaN   615        NaN          NaN               NaN
# 7          note_on       NaN    20        NaN          NaN               NaN
# 8          note_on       NaN    74        NaN          NaN               NaN
# 9   control_change       NaN   128        NaN          NaN               NaN
# 10  control_change       NaN    15        NaN          NaN               NaN
# 11  control_change       NaN    16        NaN          NaN               NaN
# 12  control_change       NaN    15        NaN          NaN               NaN
# 13         note_on       NaN    11        NaN          NaN               NaN
# 14  control_change       NaN     3        NaN          NaN               NaN
# 15         note_on       NaN     2        NaN          NaN               NaN
# 16  control_change       NaN    14        NaN          NaN               NaN
# 17         note_on       NaN     5        NaN          NaN               NaN
# 18         note_on       NaN     2        NaN          NaN               NaN
# 19  control_change       NaN     8        NaN          NaN               NaN
#
#     notated_32nd_notes_per_beat  program  channel  control  value  note  \
# 0                           NaN      NaN      NaN      NaN    NaN   NaN
# 1                           8.0      NaN      NaN      NaN    NaN   NaN
# 2                           NaN      NaN      NaN      NaN    NaN   NaN
# 3                           NaN      0.0      0.0      NaN    NaN   NaN
# 4                           NaN      NaN      0.0     64.0  127.0   NaN
# 5                           NaN      NaN      0.0      NaN    NaN  67.0
# 6                           NaN      NaN      0.0      NaN    NaN  72.0
# 7                           NaN      NaN      0.0      NaN    NaN  67.0
# 8                           NaN      NaN      0.0      NaN    NaN  72.0
# 9                           NaN      NaN      0.0     64.0  117.0   NaN
# 10                          NaN      NaN      0.0     64.0  111.0   NaN
# 11                          NaN      NaN      0.0     64.0  107.0   NaN
# 12                          NaN      NaN      0.0     64.0  103.0   NaN
# 13                          NaN      NaN      0.0      NaN    NaN  78.0
# 14                          NaN      NaN      0.0     64.0   98.0   NaN
# 15                          NaN      NaN      0.0      NaN    NaN  71.0
# 16                          NaN      NaN      0.0     64.0   93.0   NaN
# 17                          NaN      NaN      0.0      NaN    NaN  61.0
# 18                          NaN      NaN      0.0      NaN    NaN  67.0
# 19                          NaN      NaN      0.0     64.0   85.0   NaN
#
#     velocity  time_from_start
# 0        NaN                0
# 1        NaN                0
# 2        NaN                1
# 3        NaN                1
# 4        NaN                1
# 5       52.0              756
# 6       67.0             1371
# 7        0.0             1391
# 8        0.0             1465
# 9        NaN             1593
# 10       NaN             1608
# 11       NaN             1624
# 12       NaN             1639
# 13      65.0             1650
# 14       NaN             1653
# 15      45.0             1655
# 16       NaN             1669
# 17      39.0             1674
# 18      39.0             1676
# 19       NaN             1684

# %%
notes = messages[messages.type == 'note_on']
notes[['time', 'note', 'velocity', 'time_from_start']]
# Out:
#        time  note  velocity  time_from_start
# 5       755  67.0      52.0              756
# 6       615  72.0      67.0             1371
# 7        20  67.0       0.0             1391
# 8        74  72.0       0.0             1465
# 13       11  78.0      65.0             1650
# ...     ...   ...       ...              ...
# 23737    24  35.0      21.0           524155
# 23750   169  47.0       0.0           524742
# 23786    26  35.0       0.0           528043
# 23799   373  50.0       0.0           530773
# 23851    44  54.0       0.0           536573
#
# [8394 rows x 4 columns]

# %%
notes['next_start'] = notes.groupby('note').shift(-1)['time_from_start']
notes['duration'] = notes.next_start - notes.time_from_start
notes[:20]
# Out:
# C:\Users\benkc\AppData\Local\Temp\ipykernel_45464\995213935.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   notes['next_start'] = notes.groupby('note').shift(-1)['time_from_start']
# C:\Users\benkc\AppData\Local\Temp\ipykernel_45464\995213935.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   notes['duration'] = notes.next_start - notes.time_from_start
#        type  tempo  time  numerator  denominator  clocks_per_click  \
# 5   note_on    NaN   755        NaN          NaN               NaN
# 6   note_on    NaN   615        NaN          NaN               NaN
# 7   note_on    NaN    20        NaN          NaN               NaN
# 8   note_on    NaN    74        NaN          NaN               NaN
# 13  note_on    NaN    11        NaN          NaN               NaN
# 15  note_on    NaN     2        NaN          NaN               NaN
# 17  note_on    NaN     5        NaN          NaN               NaN
# 18  note_on    NaN     2        NaN          NaN               NaN
# 50  note_on    NaN   206        NaN          NaN               NaN
# 51  note_on    NaN    64        NaN          NaN               NaN
# 52  note_on    NaN   274        NaN          NaN               NaN
# 53  note_on    NaN   383        NaN          NaN               NaN
# 54  note_on    NaN   173        NaN          NaN               NaN
# 55  note_on    NaN    73        NaN          NaN               NaN
# 56  note_on    NaN   250        NaN          NaN               NaN
# 58  note_on    NaN     6        NaN          NaN               NaN
# 59  note_on    NaN     2        NaN          NaN               NaN
# 61  note_on    NaN     4        NaN          NaN               NaN
# 69  note_on    NaN   125        NaN          NaN               NaN
# 70  note_on    NaN    55        NaN          NaN               NaN
#
#     notated_32nd_notes_per_beat  program  channel  control  value  note  \
# 5                           NaN      NaN      0.0      NaN    NaN  67.0
# 6                           NaN      NaN      0.0      NaN    NaN  72.0
# 7                           NaN      NaN      0.0      NaN    NaN  67.0
# 8                           NaN      NaN      0.0      NaN    NaN  72.0
# 13                          NaN      NaN      0.0      NaN    NaN  78.0
# 15                          NaN      NaN      0.0      NaN    NaN  71.0
# 17                          NaN      NaN      0.0      NaN    NaN  61.0
# 18                          NaN      NaN      0.0      NaN    NaN  67.0
# 50                          NaN      NaN      0.0      NaN    NaN  67.0
# 51                          NaN      NaN      0.0      NaN    NaN  61.0
# 52                          NaN      NaN      0.0      NaN    NaN  78.0
# 53                          NaN      NaN      0.0      NaN    NaN  79.0
# 54                          NaN      NaN      0.0      NaN    NaN  71.0
# 55                          NaN      NaN      0.0      NaN    NaN  79.0
# 56                          NaN      NaN      0.0      NaN    NaN  79.0
# 58                          NaN      NaN      0.0      NaN    NaN  60.0
# 59                          NaN      NaN      0.0      NaN    NaN  70.0
# 61                          NaN      NaN      0.0      NaN    NaN  67.0
# 69                          NaN      NaN      0.0      NaN    NaN  79.0
# 70                          NaN      NaN      0.0      NaN    NaN  75.0
#
#     velocity  time_from_start  next_start  duration
# 5       52.0              756      1391.0     635.0
# 6       67.0             1371      1465.0      94.0
# 7        0.0             1391      1676.0     285.0
# 8        0.0             1465     16770.0   15305.0
# 13      65.0             1650      2766.0    1116.0
# 15      45.0             1655      3322.0    1667.0
# 17      39.0             1674      2492.0     818.0
# 18      39.0             1676      2428.0     752.0
# 50       0.0             2428      3671.0    1243.0
# 51       0.0             2492     12460.0    9968.0
# 52       0.0             2766     16004.0   13238.0
# 53      58.0             3149      3395.0     246.0
# 54       0.0             3322      4472.0    1150.0
# 55       0.0             3395      3645.0     250.0
# 56      69.0             3645      3944.0     299.0
# 58      46.0             3658      4156.0     498.0
# 59      64.0             3660      4031.0     371.0
# 61      56.0             3671      4092.0     421.0
# 69       0.0             3944     33754.0   29810.0
# 70      70.0             3999      4062.0      63.0

# %%
notes = notes[notes.velocity > 0]
notes
# Out:
#           type  tempo  time  numerator  denominator  clocks_per_click  \
# 5      note_on    NaN   755        NaN          NaN               NaN
# 6      note_on    NaN   615        NaN          NaN               NaN
# 13     note_on    NaN    11        NaN          NaN               NaN
# 15     note_on    NaN     2        NaN          NaN               NaN
# 17     note_on    NaN     5        NaN          NaN               NaN
# ...        ...    ...   ...        ...          ...               ...
# 23628  note_on    NaN    23        NaN          NaN               NaN
# 23693  note_on    NaN     4        NaN          NaN               NaN
# 23695  note_on    NaN     9        NaN          NaN               NaN
# 23735  note_on    NaN    54        NaN          NaN               NaN
# 23737  note_on    NaN    24        NaN          NaN               NaN
#
#        notated_32nd_notes_per_beat  program  channel  control  value  note  \
# 5                              NaN      NaN      0.0      NaN    NaN  67.0
# 6                              NaN      NaN      0.0      NaN    NaN  72.0
# 13                             NaN      NaN      0.0      NaN    NaN  78.0
# 15                             NaN      NaN      0.0      NaN    NaN  71.0
# 17                             NaN      NaN      0.0      NaN    NaN  61.0
# ...                            ...      ...      ...      ...    ...   ...
# 23628                          NaN      NaN      0.0      NaN    NaN  66.0
# 23693                          NaN      NaN      0.0      NaN    NaN  50.0
# 23695                          NaN      NaN      0.0      NaN    NaN  54.0
# 23735                          NaN      NaN      0.0      NaN    NaN  47.0
# 23737                          NaN      NaN      0.0      NaN    NaN  35.0
#
#        velocity  time_from_start  next_start  duration
# 5          52.0              756      1391.0     635.0
# 6          67.0             1371      1465.0      94.0
# 13         65.0             1650      2766.0    1116.0
# 15         45.0             1655      3322.0    1667.0
# 17         39.0             1674      2492.0     818.0
# ...         ...              ...         ...       ...
# 23628      34.0           516944    517824.0     880.0
# 23693       6.0           520414    530773.0   10359.0
# 23695      23.0           520435    536573.0   16138.0
# 23735      29.0           524124    524742.0     618.0
# 23737      21.0           524155    528043.0    3888.0
#
# [4197 rows x 16 columns]

# %%
messages[messages.note == 54]
# Out:
#           type  tempo  time  numerator  denominator  clocks_per_click  \
# 613    note_on    NaN   108        NaN          NaN               NaN
# 616    note_on    NaN     5        NaN          NaN               NaN
# 756    note_on    NaN     8        NaN          NaN               NaN
# 758    note_on    NaN    12        NaN          NaN               NaN
# 843    note_on    NaN     4        NaN          NaN               NaN
# ...        ...    ...   ...        ...          ...               ...
# 23263  note_on    NaN    46        NaN          NaN               NaN
# 23287  note_on    NaN     9        NaN          NaN               NaN
# 23313  note_on    NaN    21        NaN          NaN               NaN
# 23695  note_on    NaN     9        NaN          NaN               NaN
# 23851  note_on    NaN    44        NaN          NaN               NaN
#
#        notated_32nd_notes_per_beat  program  channel  control  value  note  \
# 613                            NaN      NaN      0.0      NaN    NaN  54.0
# 616                            NaN      NaN      0.0      NaN    NaN  54.0
# 756                            NaN      NaN      0.0      NaN    NaN  54.0
# 758                            NaN      NaN      0.0      NaN    NaN  54.0
# 843                            NaN      NaN      0.0      NaN    NaN  54.0
# ...                            ...      ...      ...      ...    ...   ...
# 23263                          NaN      NaN      0.0      NaN    NaN  54.0
# 23287                          NaN      NaN      0.0      NaN    NaN  54.0
# 23313                          NaN      NaN      0.0      NaN    NaN  54.0
# 23695                          NaN      NaN      0.0      NaN    NaN  54.0
# 23851                          NaN      NaN      0.0      NaN    NaN  54.0
#
#        velocity  time_from_start
# 613        62.0            15249
# 616         0.0            15370
# 756        79.0            19143
# 758         0.0            19174
# 843        65.0            21990
# ...         ...              ...
# 23263       0.0           501999
# 23287      32.0           502748
# 23313       0.0           503093
# 23695      23.0           520435
# 23851       0.0           536573
#
# [186 rows x 14 columns]

# %%
import matplotlib.pyplot as plt
notes.duration.hist(bins=800)
plt.xlim((0, 800))
plt.show()
